# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Im choosing a bookstore dataset

# %%
path = "../input/bookdata.csv"
df = pd.read_csv(path)
#Changing stars to category, so i can plot better
df['stars'] = df['stars'].astype('category')

# %%
df.head()
# Out:
#    availability            category  \
# 0            19             default
# 1            20             fiction
# 2            19         young adult
# 3            20             history
# 4            20  historical fiction
#
#                                          description  num_reviews  price  \
# 0  Since her assault, Miss Annette Chetwynd has b...            0  13.99
# 1  Dans une France assez proche de la nôtre, un h...            0  50.10
# 2  Patient Twenty-nine.A monster roams the halls ...            0  22.65
# 3  From a renowned historian comes a groundbreaki...            0  54.23
# 4  "Erotic and absorbing...Written with starling ...            0  53.74
#
#    price_excl_tax  price_incl_tax product_type stars  tax  \
# 0           13.99           13.99        books     2  0.0
# 1           50.10           50.10        books     1  0.0
# 2           22.65           22.65        books     1  0.0
# 3           54.23           54.23        books     5  0.0
# ...

# %%
df.shape, df.columns
# Out:
# ((998, 13),
#  Index(['availability', 'category', 'description', 'num_reviews', 'price',
#         'price_excl_tax', 'price_incl_tax', 'product_type', 'stars', 'tax',
#         'title', 'upc', 'url'],
#        dtype='object'))

# %% [markdown]
# ### Hmm, what type of catagory has what prices and stars?

# %%
plt.figure(figsize=(8,6))
sns.set_style("dark")
sns.regplot(x=df['price'][:50], y=df['stars'][:50])
# Out:
# <Axes: xlabel='price', ylabel='stars'>

# %%
df['category'].nunique()
# Out:
# 50

# %% [markdown]
# ### There are 50 different categories. Nothing seems appropiate
# ##### Maybe stars and price?

# %%
plt.figure(figsize=(8,6))
plt.title("Stars and price?")
sns.kdeplot(data=df, x='price', hue='stars', fill=True)
# Out:
# <Axes: title={'center': 'Stars and price?'}, xlabel='price', ylabel='Density'>

# %%
sns.histplot(data=df, x='price', hue='stars', fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Distribution of Prices')
plt.show()

# %%
sns.boxplot(x='product_type', y='price', data=df)
plt.title('Boxplot of Prices by Product Type')
plt.show()

# %%
sns.scatterplot(x='price', y='num_reviews', data=df)
plt.title('Scatter Plot of Price vs. Number of Reviews')
plt.show()
